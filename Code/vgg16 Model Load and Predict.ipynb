# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np

# %%
model=load_model("modelvggacc99_val_99.h5")

# %% [markdown]
# Model is Trained to predict 2 classes Real and Forged
# * 0:- Real Image
# * 1:- Forged Image

# %% [markdown]
# # Testing Real Image

# %%
image = load_img("01_049.png", target_size=(224, 224))
image = img_to_array(image)
image = image/255.0
image = np.expand_dims(image, axis = 0)

# %%
pred = model.predict(image)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000262AFBADA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000262AFBADA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1/1 [==============================] - 1s 501ms/step

# %%
pred
# Out:
# array([[1.000000e+00, 6.887178e-10]], dtype=float32)

# %%
predict =np.argmax(pred,axis=1)

# %%
predict
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # Testing Fake Image

# %%
image = load_img("01_0114049.PNG", target_size=(224, 224))
image = img_to_array(image)
image = image/255.0
image = np.expand_dims(image, axis = 0)

# %%
pred = model.predict(image)
predict =np.argmax(pred,axis=1)
predict
# Out:
# 1/1 [==============================] - 0s 263ms/step
# array([1], dtype=int64)
